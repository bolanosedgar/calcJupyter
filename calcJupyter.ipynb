# %% [markdown]
# # Calculadora Jupyter

# %%
import numpy as np
import os
from time import sleep
import math

# %%
def Sum():
    x = int(input("Ingresa el primer número\n"))
    y = int(input("Ingrese el segundo número\n"))
    arr1 = np.array([x])
    arr2 = np.array([y])
    respuesta = x + y
    print("El resultado de tu operación es\n" +str(respuesta))
    sleep(3)
    print("""
Para realizar la misma operación escribe -> Suma
Para regresar al menu principal escribe -> Menu
    """)
    option = str(input("¿Desea realizar de nuevo la operación?\n").lower())
    if (option != "Suma" or option != "Menu"):
        print("No pude entender tu respuesta, seras llevado al menu principal") 
        again()   
    elif (option == "suma"):
        Sum()
    elif (option == "menu" ):
        again()

# %%
def Calculadora():
    while True:
        print('Seleccione una operación de la lista')
        print('Menu')
        print('1) Suma')
        print('2) Resta')
        print('3) Multiplicacion')
        print('4) Division')
        print('5) raiz n')
        print('6) Exponente')
        print('7) Seno')
        print('8) Apagar o Terminar')
        opc = input("Ingresa el número de la operación deseada: ")
        try:
            opc = int(opc)
            while (opc > 0 and opc <= 8):
                if (opc > 0 and opc <= 8):
                    if (opc == 1):
                        Sum()
                    elif (opc == 2):
                        Resta()
                    elif (opc == 3):
                        Multiplicacion()
                    elif (opc == 4):
                        Division()
                    elif (opc == 5):
                        Raiz()
                    elif (opc == 6):
                        Exponente()
                    elif (opc == 7):
                        Sen()
                    elif (opc >= 8):
                        print("""
                        
Adios, gracias por usar mi calculadora
""")
                        quit()
        except ValueError:
            print("""
            
La entrada es incorrecta: escribe un número entero
""")
            sleep(3)
            again()

############################################################################################################

def Sum():
    x = int(input("Ingresa el primer número\n"))
    y = int(input("Ingrese el segundo número\n"))
    arr1 = np.array([x])
    arr2 = np.array([y])
    respuesta = x + y
    print("El resultado de tu operación es\n" +str(respuesta))
    sleep(3)
    print("""
Para realizar la misma operación escribe -> Suma
Para regresar al menu principal escribe -> Menu
    """)
while True:
    option = str(input("¿Desea realizar de nuevo la operación?\n").lower())
    if (option != "Suma" or option != "Menu"):
        print("No pude entender tu respuesta, seras llevado al menu principal")   
    elif (option == "suma"):
        Sum()
    elif (option == "menu" ):
        again()

############################################################################################################

def again():
    try:
        while True:
            os.system("cls")  # limpia la consola
            Calculadora()
    except KeyboardInterrupt:
        os.system("cls")  # limpia la consola
        again()



again()
